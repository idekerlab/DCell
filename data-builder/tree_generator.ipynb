# %%
# !python --version

# !wget http://geneontology.org/gene-associations/gene_association.sgd.gz -O ./data/gene_association.sgd.gz
# !wget http://purl.obolibrary.org/obo/go.obo -O ./data/go.obo
# Out:
# Python 3.5.2 :: Anaconda custom (x86_64)
# --2016-12-23 14:35:57--  http://geneontology.org/gene-associations/gene_association.sgd.gz
# Resolving geneontology.org... 52.27.86.54
# Connecting to geneontology.org|52.27.86.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1495883 (1.4M) [application/x-gzip]
# Saving to: ‘./data/gene_association.sgd.gz’
#
# ./data/gene_associa 100%[===================>]   1.43M  4.37MB/s    in 0.3s
#
# 2016-12-23 14:35:58 (4.37 MB/s) - ‘./data/gene_association.sgd.gz’ saved [1495883/1495883]
#
# --2016-12-23 14:35:58--  http://purl.obolibrary.org/obo/go.obo
# Resolving purl.obolibrary.org... 52.3.123.63
# Connecting to purl.obolibrary.org|52.3.123.63|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://geneontology.org/ontology/go.obo [following]
# --2016-12-23 14:35:58--  http://geneontology.org/ontology/go.obo
# Resolving geneontology.org... 52.27.86.54
# Connecting to geneontology.org|52.27.86.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35856135 (34M) [text/plain]
# Saving to: ‘./data/go.obo’
#
# ./data/go.obo       100%[===================>]  34.19M  15.3MB/s    in 2.2s
#
# 2016-12-23 14:36:01 (15.3 MB/s) - ‘./data/go.obo’ saved [35856135/35856135]

# %% [markdown]
# # Ontology Tree Generator
#
# This is a notebook to generate tree data file from original table and annotations.

# %%
import pandas as pd
from goatools import obo_parser

# %%
# Latest data sources

treeSourceUrl = 'http://chianti.ucsd.edu/~kono/ci/data/collapsed_go.no_IGI.propagated.small_parent_tree'
oboUrl = './data/go.obo'
yeastAnnotationUrl = './data/gene_association.sgd.gz'
kegg2goUrl = 'http://geneontology.org/external2go/kegg2go'
reactome2go = 'http://geneontology.org/external2go/reactome2go'

phenotypeUrl='http://downloads.yeastgenome.org/curation/literature/phenotype_data.tab'

# %%
# Load the tree data
treeColNames = ['parent', 'child', 'type', 'in_tree']
tree = pd.read_csv(treeSourceUrl, delimiter='\t', names=treeColNames)
tree.tail(10)
# Out:
#             parent    child  type   in_tree
# 441927  GO:0090150  YHR083W  gene  NOT_TREE
# 441928  GO:0005575  YHR083W  gene  NOT_TREE
# 441929  GO:0098796  YHR083W  gene  NOT_TREE
# 441930  GO:1902589  YHR083W  gene  NOT_TREE
# 441931  GO:0044085  YHR083W  gene  NOT_TREE
# 441932  GO:0015031  YHR083W  gene  NOT_TREE
# 441933  GO:1902582  YHR083W  gene  NOT_TREE
# 441934  GO:1902580  YHR083W  gene  NOT_TREE
# 441935  GO:0098799  YHR083W  gene  NOT_TREE
# 441936  GO:0098798  YHR083W  gene  NOT_TREE

# %% [markdown]
# ## Parse yeast annotation file

# %%
cols = pd.read_csv('./annotation_columns.txt', names=['col_names'])
col_names = cols['col_names'].tolist()
print(col_names)
# Out:
# ['DB', 'DB_Object_ID', 'DB_Object_Symbol', 'Qualifier', 'GO_ID', 'DB:Reference', 'Evidence', 'With_or_From', 'Aspect', 'DB_Object_Name', 'DB_Object_Synonym', 'DB_Object_Type', 'taxon', 'Date', 'Assigned_by', 'Annotation_Extension', 'Gene_Product_Form_ID']

# %%
yeastAnnotation = pd.read_csv(yeastAnnotationUrl, delimiter='\t', comment='!', compression='gzip', names=col_names)
yeastAnnotation.head()
# Out:
#     DB DB_Object_ID DB_Object_Symbol Qualifier       GO_ID  \
# 0  SGD   S000007287         15S_RRNA       NaN  GO:0005763
# 1  SGD   S000007287         15S_RRNA       NaN  GO:0032543
# 2  SGD   S000007287         15S_RRNA       NaN  GO:0003735
# 3  SGD   S000007288         21S_RRNA       NaN  GO:0005762
# 4  SGD   S000007288         21S_RRNA       NaN  GO:0032543
#
#                       DB:Reference Evidence With_or_From Aspect  \
# 0  SGD_REF:S000073641|PMID:6262728      IDA          NaN      C
# 1  SGD_REF:S000073641|PMID:6262728       IC   GO:0005763      P
# 2  SGD_REF:S000073641|PMID:6262728       IC   GO:0005763      F
# 3  SGD_REF:S000073372|PMID:6759872      IDA          NaN      C
# 4  SGD_REF:S000073372|PMID:6759872      IMP          NaN      P
#
#                                       DB_Object_Name  \
# 0  Ribosomal RNA of the small mitochondrial ribos...
# 1  Ribosomal RNA of the small mitochondrial ribos...
# 2  Ribosomal RNA of the small mitochondrial ribos...
# 3                             Mitochondrial 21S rRNA
# 4                             Mitochondrial 21S rRNA
#
#              DB_Object_Synonym DB_Object_Type         taxon      Date  \
# 0    Q0020|14s rRNA|15S_RRNA_2           gene  taxon:559292  20150612
# 1    Q0020|14s rRNA|15S_RRNA_2           gene  taxon:559292  20150612
# 2    Q0020|14s rRNA|15S_RRNA_2           gene  taxon:559292  20150612
# 3  Q0158|21S_rRNA_3|21S_rRNA_4           gene  taxon:559292  20040202
# 4  Q0158|21S_rRNA_3|21S_rRNA_4           gene  taxon:559292  20100715
#
#   Assigned_by Annotation_Extension  Gene_Product_Form_ID
# 0         SGD                  NaN                   NaN
# 1         SGD                  NaN                   NaN
# 2         SGD                  NaN                   NaN
# 3         SGD                  NaN                   NaN
# 4         SGD                  NaN                   NaN

# %% [markdown]
# ## Parse OBO

# %%
obo = obo_parser.GODag(oboUrl)
# Out:
# load obo file ./data/go.obo
# ./data/go.obo: fmt(1.2) rel(2016-12-06) 47,833 GO Terms

# %%
obo['GO:1902580'].name
# Out:
# 'single-organism cellular localization'

# %%
ph = pd.read_csv(phenotypeUrl, delimiter='\t')
ph.head()
# Out:
#     IMI1  not in systematic sequence of S288C IMI1.1  S000149345  \
# 0   IMI1  not in systematic sequence of S288C   IMI1  S000149345
# 1   IMI1  not in systematic sequence of S288C   IMI1  S000149345
# 2   IMI1  not in systematic sequence of S288C   IMI1  S000149345
# 3  MAL62  not in systematic sequence of S288C  MAL62  S000029690
# 4  MATA1  not in systematic sequence of S288C  MATA1  S000029660
#
#    PMID: 26091838|SGD_REF: S000180603  classical genetics            null     \
# 0  PMID: 26091838|SGD_REF: S000180603  classical genetics            null
# 1  PMID: 26091838|SGD_REF: S000180603  classical genetics            null
# 2  PMID: 26091838|SGD_REF: S000180603  classical genetics            null
# 3  PMID: 22669197|SGD_REF: S000149697  classical genetics  overexpression
# 4   PMID: 8065362|SGD_REF: S000039420  classical genetics  overexpression
#
#            W303 mitochondrial genome maintenance: abnormal             .1  \
# 0          W303          respiratory metabolism: decreased  glycerol (2%)
# 1          W303         mitochondrial morphology: abnormal
# 2          W303                                     viable
# 3         Other             fermentative growth: increased        maltose
# 4  Other (LL20)         killer toxin resistance: increased
#
#                              .2  \
# 0  nonfermentable carbon source
# 1
# 2
# 3
# 4
#
#                                                   .3  .4
# 0           similar results with ethanol and lactate
# 1
# 2
# 3  maltose fementation and leavening ability are ...
# 4                                  K. lactis zymocin

# %% [markdown]
# ## Build Base CyJS Network

# %%
import json

goTree = {
    'data': {
        'name': 'GO Merged Tree'
    },
    'elements': {
        'nodes': [],
        'edges': []
    }
}

print(json.dumps(goTree, indent=4))
# Out:
# {
#     "elements": {
#         "edges": [],
#         "nodes": []
#     },
#     "data": {
#         "name": "GO Merged Tree"
#     }
# }

# %%
node_set= set()

row = next(tree.iterrows())[1]
print(row)
print(row['parent'])
# Out:
# parent     GO:0046434
# child      GO:0009395
# type             is_a
# in_tree          TREE
# Name: 0, dtype: object
# GO:0046434

# %%
def get_node(id, name):
    node = {
        'data': {
            'id': id
        }
    }
    
    if id in obo.keys():
        go = obo[id]
        node['data']['name'] = go.name
        node['data']['namespace'] = go.namespace
        
    return node

def get_edge(source, target, itr, is_tree):
    edge = {
        'data': {
            'source': source,
            'target': target,
            'interaction': itr,
            'is_tree': is_tree
        }
    }
    
    return edge

# %%
edges = []
for data in tree.iterrows():
    row=data[1]
    node_set.add(row['parent'])
    node_set.add(row['child'])
    edges.append(get_edge(row['parent'], row['child'], row['type'], row['in_tree']))

# %%
nodes = []

for id in node_set:
    node = get_node(id)
    nodes.append(node)

# %%
print(len(nodes))
print(nodes[0])
print(len(edges))
edges[0]
# Out:
# 13037
# {'data': {'namespace': 'biological_process', 'id': 'GO:0043648', 'name': 'dicarboxylic acid metabolic process'}}
# 441937
# {'data': {'interaction': 'is_a',
#   'is_tree': 'TREE',
#   'source': 'GO:0046434',
#   'target': 'GO:0009395'}}

# %%
goTree['elements']['nodes'] = nodes
goTree['elements']['edges'] = edges

with open('./data/tree.cyjs', 'w') as outfile:
    json.dump(goTree, outfile)

# %%
yeastAnnotation['DB_Object_Synonym'] = yeastAnnotation['DB_Object_Synonym'].fillna('')

# %%
result = yeastAnnotation[yeastAnnotation['DB_Object_Synonym'].str.contains('YHR083W')]
result
# Out:
#         DB DB_Object_ID DB_Object_Symbol Qualifier       GO_ID  \
# 76224  SGD   S000001125            SAM35       NaN  GO:0005739
# 76225  SGD   S000001125            SAM35       NaN  GO:0003674
# 76226  SGD   S000001125            SAM35       NaN  GO:0005741
# 76227  SGD   S000001125            SAM35       NaN  GO:0001401
# 76228  SGD   S000001125            SAM35       NaN  GO:0045040
# 76229  SGD   S000001125            SAM35       NaN  GO:0005739
# 76230  SGD   S000001125            SAM35       NaN  GO:0001401
# 76231  SGD   S000001125            SAM35       NaN  GO:0001401
# 76232  SGD   S000001125            SAM35       NaN  GO:0005741
# 76233  SGD   S000001125            SAM35       NaN  GO:0006810
# 76234  SGD   S000001125            SAM35       NaN  GO:0016020
# 76235  SGD   S000001125            SAM35       NaN  GO:0015031
# 76236  SGD   S000001125            SAM35       NaN  GO:0005739
# 76237  SGD   S000001125            SAM35       NaN  GO:0070096
# 76238  SGD   S000001125            SAM35       NaN  GO:0070096
# 76239  SGD   S000001125            SAM35       NaN  GO:0070096
# 76240  SGD   S000001125            SAM35       NaN  GO:0045040
# 76241  SGD   S000001125            SAM35       NaN  GO:0005741
# 76242  SGD   S000001125            SAM35       NaN  GO:0045040
# 76243  SGD   S000001125            SAM35       NaN  GO:0005741
# 76244  SGD   S000001125            SAM35       NaN  GO:0005741
#
#                            DB:Reference Evidence               With_or_From  \
# 76224  SGD_REF:S000117178|PMID:16823961      IDA                        NaN
# 76225                SGD_REF:S000069584       ND                        NaN
# 76226  SGD_REF:S000076328|PMID:15067005      IDA                        NaN
# 76227  SGD_REF:S000076328|PMID:15067005      IDA                        NaN
# 76228  SGD_REF:S000076328|PMID:15067005      IMP                        NaN
# 76229  SGD_REF:S000175707|PMID:24769239      IDA                        NaN
# 76230  SGD_REF:S000076561|PMID:15205677      IDA                        NaN
# 76231  SGD_REF:S000076561|PMID:15205677      IMP                        NaN
# 76232  SGD_REF:S000076561|PMID:15205677      IDA                        NaN
# 76233                SGD_REF:S000148669      IEA       UniProtKB-KW:KW-0813
# 76234                SGD_REF:S000148669      IEA       UniProtKB-KW:KW-0472
# 76235                SGD_REF:S000148669      IEA       UniProtKB-KW:KW-0653
# 76236                SGD_REF:S000148669      IEA       UniProtKB-KW:KW-0496
# 76237  SGD_REF:S000076328|PMID:15067005      IMP                        NaN
# 76238  SGD_REF:S000126649|PMID:18039934      IMP                        NaN
# 76239  SGD_REF:S000076561|PMID:15205677      IMP                        NaN
# 76240  SGD_REF:S000077462|PMID:15326197      IMP                        NaN
# 76241                SGD_REF:S000148671      IEA  UniProtKB-SubCell:SL-0172
# 76242  SGD_REF:S000126649|PMID:18039934      IMP                        NaN
# 76243                SGD_REF:S000148669      IEA       UniProtKB-KW:KW-1000
# 76244  SGD_REF:S000114057|PMID:16407407      IDA                        NaN
#
#       Aspect                                     DB_Object_Name  \
# 76224      C  Component of the sorting and assembly machiner...
# 76225      F  Component of the sorting and assembly machiner...
# 76226      C  Component of the sorting and assembly machiner...
# 76227      C  Component of the sorting and assembly machiner...
# 76228      P  Component of the sorting and assembly machiner...
# 76229      C  Component of the sorting and assembly machiner...
# 76230      C  Component of the sorting and assembly machiner...
# 76231      C  Component of the sorting and assembly machiner...
# 76232      C  Component of the sorting and assembly machiner...
# 76233      P  Component of the sorting and assembly machiner...
# 76234      C  Component of the sorting and assembly machiner...
# 76235      P  Component of the sorting and assembly machiner...
# 76236      C  Component of the sorting and assembly machiner...
# 76237      P  Component of the sorting and assembly machiner...
# 76238      P  Component of the sorting and assembly machiner...
# 76239      P  Component of the sorting and assembly machiner...
# 76240      P  Component of the sorting and assembly machiner...
# 76241      C  Component of the sorting and assembly machiner...
# 76242      P  Component of the sorting and assembly machiner...
# 76243      C  Component of the sorting and assembly machiner...
# 76244      C  Component of the sorting and assembly machiner...
#
#                                        DB_Object_Synonym DB_Object_Type  \
# 76224  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76225  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76226  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76227  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76228  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76229  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76230  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76231  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76232  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76233  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76234  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76235  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76236  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76237  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76238  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76239  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76240  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76241  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76242  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76243  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
# 76244  YHR083W|FMP20|SAM complex subunit SAM35|TOB38|...           gene
#
#               taxon      Date Assigned_by Annotation_Extension  \
# 76224  taxon:559292  20061212         SGD                  NaN
# 76225  taxon:559292  20090409         SGD                  NaN
# 76226  taxon:559292  20040909         SGD                  NaN
# 76227  taxon:559292  20040909         SGD                  NaN
# 76228  taxon:559292  20040909         SGD                  NaN
# 76229  taxon:559292  20150803         SGD                  NaN
# 76230  taxon:559292  20040707         SGD                  NaN
# 76231  taxon:559292  20040707         SGD                  NaN
# 76232  taxon:559292  20040707         SGD                  NaN
# 76233  taxon:559292  20161112     UniProt                  NaN
# 76234  taxon:559292  20161112     UniProt                  NaN
# 76235  taxon:559292  20161112     UniProt                  NaN
# 76236  taxon:559292  20161112     UniProt                  NaN
# 76237  taxon:559292  20090409         SGD                  NaN
# 76238  taxon:559292  20090409         SGD                  NaN
# 76239  taxon:559292  20090409         SGD                  NaN
# 76240  taxon:559292  20090409         SGD                  NaN
# 76241  taxon:559292  20161112     UniProt                  NaN
# 76242  taxon:559292  20090409         SGD                  NaN
# 76243  taxon:559292  20161112     UniProt                  NaN
# 76244  taxon:559292  20060317         SGD                  NaN
#
#        Gene_Product_Form_ID
# 76224                   NaN
# 76225                   NaN
# 76226                   NaN
# 76227                   NaN
# 76228                   NaN
# 76229                   NaN
# 76230                   NaN
# 76231                   NaN
# 76232                   NaN
# 76233                   NaN
# 76234                   NaN
# 76235                   NaN
# 76236                   NaN
# 76237                   NaN
# 76238                   NaN
# 76239                   NaN
# 76240                   NaN
# 76241                   NaN
# 76242                   NaN
# 76243                   NaN
# 76244                   NaN
