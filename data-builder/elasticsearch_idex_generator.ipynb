# %%
# !python --version

# !wget http://geneontology.org/gene-associations/gene_association.sgd.gz -O ./data/gene_association.sgd.gz
# !wget http://purl.obolibrary.org/obo/go.obo -O ./data/go.obo
# Out:
# Python 3.5.2 :: Anaconda custom (x86_64)
# --2017-01-10 16:08:34--  http://geneontology.org/gene-associations/gene_association.sgd.gz
# Resolving geneontology.org... 52.27.86.54
# Connecting to geneontology.org|52.27.86.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1497624 (1.4M) [application/x-gzip]
# Saving to: ‘./data/gene_association.sgd.gz’
#
# ./data/gene_associa 100%[===================>]   1.43M  3.98MB/s    in 0.4s
#
# 2017-01-10 16:08:35 (3.98 MB/s) - ‘./data/gene_association.sgd.gz’ saved [1497624/1497624]
#
# --2017-01-10 16:08:35--  http://purl.obolibrary.org/obo/go.obo
# Resolving purl.obolibrary.org... 52.3.123.63
# Connecting to purl.obolibrary.org|52.3.123.63|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://geneontology.org/ontology/go.obo [following]
# --2017-01-10 16:08:35--  http://geneontology.org/ontology/go.obo
# Resolving geneontology.org... 52.27.86.54
# Connecting to geneontology.org|52.27.86.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35881945 (34M) [text/plain]
# Saving to: ‘./data/go.obo’
#
# ./data/go.obo       100%[===================>]  34.22M  14.5MB/s    in 2.4s
#
# 2017-01-10 16:08:38 (14.5 MB/s) - ‘./data/go.obo’ saved [35881945/35881945]

# %% [markdown]
# # Term Property Generator
#
# ## Introduction
#
# This is a script to convert public data sets into a searchable, local Elasticsearch DB.
#
# ## Requirments
# * Python 3.x
# * Elasticsearch 5.x
# *

# %%
from elasticsearch import Elasticsearch
from datetime import datetime
from elasticsearch_dsl import DocType, Date, Integer, Keyword, Text, Object, Nested, Index
from elasticsearch_dsl.connections import connections
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from elasticsearch_dsl import Search
import pandas as pd

from elasticsearch_dsl.query import MultiMatch, Match, Q


# Define a default Elasticsearch client
connections.create_connection(hosts=['localhost:9200'])

treeSourceUrl = 'http://chianti.ucsd.edu/~kono/ci/data/collapsed_go.no_IGI.propagated.small_parent_tree'
oboUrl = './data/go.obo'
yeastAnnotationUrl = './data/gene_association.sgd.gz'
kegg2goUrl = 'http://geneontology.org/external2go/kegg2go'
reactome2go = 'http://geneontology.org/external2go/reactome2go'

phenotypeUrl='http://downloads.yeastgenome.org/curation/literature/phenotype_data.tab'

# %% [markdown]
# ## Load gene associations

# %%
yeastAnnotationUrl = './data/gene_association.sgd.gz'
cols = pd.read_csv('./annotation_columns.txt', names=['col_names'])
col_names = cols['col_names'].tolist()
print(col_names)

yeastAnnotation = pd.read_csv(yeastAnnotationUrl, delimiter='\t', comment='!', compression='gzip', names=col_names)
yeastAnnotation.tail()
# Out:
# ['DB', 'DB_Object_ID', 'DB_Object_Symbol', 'Qualifier', 'GO_ID', 'DB:Reference', 'Evidence', 'With_or_From', 'Aspect', 'DB_Object_Name', 'DB_Object_Synonym', 'DB_Object_Type', 'taxon', 'Date', 'Assigned_by', 'Annotation_Extension', 'Gene_Product_Form_ID']
#          DB DB_Object_ID DB_Object_Symbol Qualifier       GO_ID  \
# 111269  SGD   S000006732         tX(XXX)L       NaN  GO:0030533
# 111270  SGD   S000006732         tX(XXX)L       NaN  GO:0005829
# 111271  SGD   S000007338         tY(GUA)Q       NaN  GO:0070125
# 111272  SGD   S000007338         tY(GUA)Q       NaN  GO:0005739
# 111273  SGD   S000007338         tY(GUA)Q       NaN  GO:0030533
#
#                            DB:Reference Evidence With_or_From Aspect  \
# 111269  SGD_REF:S000181097|PMID:9023104      ISM          NaN      F
# 111270  SGD_REF:S000181097|PMID:9023104       IC   GO:0030533      C
# 111271  SGD_REF:S000181097|PMID:9023104       IC   GO:0030533      P
# 111272  SGD_REF:S000181097|PMID:9023104       IC   GO:0030533      C
# 111273  SGD_REF:S000181097|PMID:9023104      ISM          NaN      F
#
#                                            DB_Object_Name  DB_Object_Synonym  \
# 111269  tRNA of undetermined specificity, predicted by...  tX(XXX)L|tS(GCU)L
# 111270  tRNA of undetermined specificity, predicted by...  tX(XXX)L|tS(GCU)L
# 111271             Mitochondrial tyrosine tRNA (tRNA-Tyr)           tY(GUA)Q
# 111272             Mitochondrial tyrosine tRNA (tRNA-Tyr)           tY(GUA)Q
# 111273             Mitochondrial tyrosine tRNA (tRNA-Tyr)           tY(GUA)Q
#
#        DB_Object_Type         taxon      Date Assigned_by  \
# 111269           gene  taxon:559292  20030507         SGD
# 111270           gene  taxon:559292  20030507         SGD
# 111271           gene  taxon:559292  20150730         SGD
# 111272           gene  taxon:559292  20030507         SGD
# 111273           gene  taxon:559292  20060721         SGD
#
#        Annotation_Extension  Gene_Product_Form_ID
# 111269                  NaN                   NaN
# 111270                  NaN                   NaN
# 111271                  NaN                   NaN
# 111272                  NaN                   NaN
# 111273                  NaN                   NaN

# %% [markdown]
# ## Phenotype

# %%
pUrl = 'http://downloads.yeastgenome.org/curation/literature/phenotype_data.tab'

p_cols = pd.read_csv('./p_cols.txt', names=['col_names'])
p_col_names = p_cols['col_names'].tolist()
print(p_col_names)

phenotype = pd.read_csv(pUrl, delimiter='\t', names=p_col_names)
# Out:
# ['Feature_Name', 'Feature_Type', 'Gene_Name', 'SGDID', 'Reference', 'Experiment_Type', 'Mutant_Type', 'Allele', 'Strain_Background', 'Phenotype', 'Chemical', 'Condition', 'Details', 'Reporter']

# %% [markdown]
# ## ID Mapping Table

# %%
idmap = pd.read_csv('./yeast_clean4.txt', delimiter='\t')
idmap.head()
# Out:
#   symbol locus_name acc_number   swiss-prot         sgd sequence_length   3d  \
# 0   AAC1    YMR056C     P04710   ADT1_YEAST  S000004660             309   13
# 1   AAC3    YBR085W     P18238   ADT3_YEAST  S000000289             307  (3)
# 2  AAD10    YJR155W     P47182  AAD10_YEAST  S000003916             288   10
# 3  AAD14    YNL331C     P42884  AAD14_YEAST  S000005275             376   14
# 4  AAD15    YOL165C     Q08361  AAD15_YEAST  S000005525             143   15
#
#   chromosome
# 0        NaN
# 1          2
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Create usuful map for ID mapping
sgd2info = {}

for idx, row in idmap.iterrows():
    entry = {}
    entry['locus'] = row['locus_name']
    entry['acc'] = row['acc_number']
    entry['swiss'] = row['swiss-prot']
    entry['length'] = row['sequence_length']
    
    symbols = row['symbol'].split(';')
    entry['symbol'] = symbols[0]
    
    if len(symbols) == 1:
        entry['alt_symbols'] = []
    else:
        entry['alt_symbols'] = symbols[1:]
    
    if row['3d'] == '(3)':
        entry['3d_struct_available'] = True
        entry['chromosome'] = row['chromosome']
    else:
        entry['3d_struct_available'] = False
        entry['chromosome'] = row['3d']
    
    sgd2info[row['sgd']] = entry

# %%
sgd2info['S000005299']
# Out:
# {'3d_struct_available': True,
#  'acc': 'Q00955',
#  'alt_symbols': ['ABP2', 'FAS3', 'MTR7'],
#  'chromosome': '14',
#  'length': '2233',
#  'locus': 'YNR016C',
#  'swiss': 'ACAC_YEAST',
#  'symbol': 'ACC1'}

# %% [markdown]
# ## Define GO Term Entry

# %%
# Map from GO Term to genes
go2gene = {}

go2idset = {}

for idx, row in yeastAnnotation.iterrows():
    goterm = row['GO_ID']
    gene_id = row['DB_Object_ID']
    symbol = row['DB_Object_Symbol']
    full_name = str(row['DB_Object_Name']).replace('\r\n', '')
    
    
    # for gene info
    if gene_id in sgd2info:
        entry = sgd2info[gene_id]
        entry['name'] = full_name
    
    cur_entry = []
    
    if goterm in go2gene:
        cur_entry = go2gene[goterm]
        gene_set = go2idset[goterm]
    else:
        gene_set = set()
        go2idset[goterm] = gene_set
    
    ids = go2idset[goterm]
    
    if gene_id not in ids:
        gene = {
            'sgdid': gene_id,
            'symbol': symbol,
            'name': full_name
        }
    
        ids.add(gene_id)
        go2idset[goterm] = ids
        
        cur_entry.append(gene)
        go2gene[goterm] = cur_entry

# %%
sgd2info['S000005299']
# Out:
# {'3d_struct_available': True,
#  'acc': 'Q00955',
#  'alt_symbols': ['ABP2', 'FAS3', 'MTR7'],
#  'chromosome': '14',
#  'length': '2233',
#  'locus': 'YNR016C',
#  'name': 'Acetyl-CoA carboxylase, biotin containing enzyme',
#  'swiss': 'ACAC_YEAST',
#  'symbol': 'ACC1'}

# %%
class GoTerm(DocType):
    termid = Text(index='not_analyzed')
    name = Text(analyzer='standard')
    namespace = Text(analyzer='standard')
    definition = Text(analyzer='standard')
    parents = Object(multi=True)
    children = Object(multi=True)

    genes = Object(multi=True)
    
    class Meta:
        index = 'terms'

class Gene(DocType):
    id = Text(index='not_analyzed')
    symbol = Text(analyzer='standard')
    name = Text(analyzer='standard')
    synonyms = Text(analyzer='standard', multi=True)
    locus = Text(analyzer='standard')
    
    class Meta:
        index = 'genes'

# %%
GoTerm.init()
Gene.init()

# %%
from goatools import obo_parser
oboUrl = './data/go.obo'
obo = obo_parser.GODag(oboUrl, optional_attrs=['def'])
# Out:
# load obo file ./data/go.obo
# ./data/go.obo: fmt(1.2) rel(2017-01-10) 47,923 GO Terms

# %%
def get_go_term(term):
    g = {}
    if term.id in go2gene:
        g = go2gene[term.id]
    
    parents = []
    children = []
    
    for p in term.parents:
        parents.append({'id': p.id, 'name': p.name})
    for c in term.children:
        children.append({'id': c.id, 'name': c.name})
    
    definition = term.defn.split('"')[1]
        
    return GoTerm(
        meta={'id':  term.id},
        termid=term.id,
        name=term.name,
        namespace=term.namespace,
        definition=definition,
        parents=parents,
        children=children,
        genes=g
)

print(connections.get_connection().cluster.health())
# Out:
# {'number_of_data_nodes': 1, 'initializing_shards': 0, 'number_of_in_flight_fetch': 0, 'status': 'yellow', 'unassigned_shards': 10, 'active_shards_percent_as_number': 50.0, 'number_of_nodes': 1, 'cluster_name': 'elasticsearch', 'active_shards': 10, 'delayed_unassigned_shards': 0, 'task_max_waiting_in_queue_millis': 0, 'number_of_pending_tasks': 0, 'timed_out': False, 'relocating_shards': 0, 'active_primary_shards': 10}

# %%
def get_gene(gene, id):
    name = ''
    if 'name' in gene:
        name = gene['name']
    
    return Gene(
        meta={'id':  id},
        id = id,
        symbol = gene['symbol'],
        name = name,
        synonyms = gene['alt_symbols'],
        locus = gene['locus']
)

# %%
es = Elasticsearch(host='localhost', port=9200)
pool = []

# %%
term_ids = obo.keys()
print(len(term_ids))

for id in term_ids:    
    d = get_go_term(obo[id])
    term = {'_index': getattr(d.meta, 'index', d._doc_type.index), '_type': d._doc_type.name,  '_id': d.termid, '_source': d.to_dict()}
    pool.append(term)
    if len(pool) > 5000:
        print('Bulk add start:')
        helpers.bulk(es, pool)
        print('Bulk add success!')

        pool = []

if len(pool) > 0:
    print('Last: ' + str(len(pool)))
    helpers.bulk(es, pool)
    print('---------------success!')
# Out:
# 47923
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Bulk add start:
# Bulk add success!
# Last: 2914
# ---------------success!

# %%
ids = sgd2info.keys()

print(len(ids))

for id in ids:    
    d = get_gene(sgd2info[id], id)
    term = {'_index': getattr(d.meta, 'index', d._doc_type.index), '_type': d._doc_type.name, '_id': d.id, '_source': d.to_dict()}
    pool.append(term)
    if len(pool) > 5000:
        print('Bulk add start:')
        helpers.bulk(es, pool)
        print('Bulk add success!')

        pool = []

if len(pool) > 0:
    print('Last: ' + str(len(pool)))
    helpers.bulk(es, pool)
    print('---------------success!')
# Out:
# 6724
# Bulk add start:
# Bulk add success!
# Last: 4637
# ---------------success!

# %%
s = Search(using=es, index="_all").query("match", name='proteasome')

# %%
response = s.execute()

# %%
import json

for hit in response:
    print(json.dumps(hit.to_dict(), indent=4))
# Out:
# {
#     "definition": "Any process in which the proteasome is transported to, or maintained in, a specific location.",
#     "namespace": "biological_process",
#     "parents": [
#         {
#             "id": "GO:0034629",
#             "name": "cellular protein complex localization"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000005133",
#             "symbol": "SRP1",
#             "name": "Karyopherin alpha homolog"
#         },
#         {
#             "sgdid": "S000001450",
#             "symbol": "STS1",
#             "name": "Protein required for localizing proteasomes to the nucleus"
#         }
#     ],
#     "termid": "GO:0031144",
#     "children": [
#         {
#             "id": "GO:1990920",
#             "name": "proteasome localization to nuclear periphery"
#         }
#     ],
#     "name": "proteasome localization"
# }
# {
#     "definition": "A large multisubunit complex which catalyzes protein degradation, found in eukaryotes, archaea and some bacteria. In eukaryotes, this complex consists of the barrel shaped proteasome core complex and one or two associated proteins or complexes that act in regulating entry into or exit from the core.",
#     "namespace": "cellular_component",
#     "parents": [
#         {
#             "id": "GO:0043234",
#             "name": "protein complex"
#         },
#         {
#             "id": "GO:0044424",
#             "name": "intracellular part"
#         },
#         {
#             "id": "GO:1905369",
#             "name": "endopeptidase complex"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000001689",
#             "symbol": "ADD66",
#             "name": "Protein involved in 20S proteasome assembly"
#         },
#         {
#             "sgdid": "S000001887",
#             "symbol": "BLM10",
#             "name": "Proteasome activator"
#         },
#         {
#             "sgdid": "S000001094",
#             "symbol": "CIC1",
#             "name": "Essential protein that interacts with proteasome components"
#         },
#         {
#             "sgdid": "S000002476",
#             "symbol": "DOA4",
#             "name": "Ubiquitin hydrolase"
#         },
#         {
#             "sgdid": "S000001022",
#             "symbol": "ECM29",
#             "name": "Scaffold protein"
#         },
#         {
#             "sgdid": "S000004442",
#             "symbol": "HMG2",
#             "name": "HMG-CoA reductase"
#         },
#         {
#             "sgdid": "S000003109",
#             "symbol": "HUL5",
#             "name": "Multiubiquitin chain assembly factor (E4)"
#         },
#         {
#             "sgdid": "S000000814",
#             "symbol": "PRE1",
#             "name": "Beta 4 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000005889",
#             "symbol": "PRE10",
#             "name": "Alpha 7 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000006307",
#             "symbol": "PRE2",
#             "name": "Beta 5 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000003538",
#             "symbol": "PRE3",
#             "name": "Beta 1 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000001946",
#             "symbol": "PRE4",
#             "name": "Beta 7 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000004931",
#             "symbol": "PRE5",
#             "name": "Alpha 6 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000005398",
#             "symbol": "PRE6",
#             "name": "Alpha 4 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000000137",
#             "symbol": "PRE7",
#             "name": "Beta 6 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000004557",
#             "symbol": "PRE8",
#             "name": "Alpha 2 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000003367",
#             "symbol": "PRE9",
#             "name": "Alpha 3 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000005683",
#             "symbol": "PUP1",
#             "name": "Beta 2 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000003485",
#             "symbol": "PUP2",
#             "name": "Alpha 5 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000000896",
#             "symbol": "PUP3",
#             "name": "Beta 3 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000000763",
#             "symbol": "RAD23",
#             "name": "Protein with ubiquitin-like N terminus"
#         },
#         {
#             "sgdid": "S000003026",
#             "symbol": "RAD6",
#             "name": "Ubiquitin-conjugating enzyme (E2)"
#         },
#         {
#             "sgdid": "S000001069",
#             "symbol": "RPN1",
#             "name": "Non-ATPase base subunit of the 19S RP of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000001243",
#             "symbol": "RPN10",
#             "name": "Non-ATPase base subunit of the 19S RP of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000001900",
#             "symbol": "RPN11",
#             "name": "Metalloprotease subunit of 19S regulatory particle"
#         },
#         {
#             "sgdid": "S000001948",
#             "symbol": "RPN12",
#             "name": "Subunit of the 19S regulatory particle of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000004413",
#             "symbol": "RPN13",
#             "name": "Subunit of the 19S regulatory particle of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000002972",
#             "symbol": "RPN14",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000001337",
#             "symbol": "RPN2",
#             "name": "Subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000000823",
#             "symbol": "RPN3",
#             "name": "Essential non-ATPase regulatory subunit of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000002306",
#             "symbol": "RPN5",
#             "name": "Subunit of the CSN and 26S proteasome lid complexes"
#         },
#         {
#             "sgdid": "S000002255",
#             "symbol": "RPN6",
#             "name": "Essential, non-ATPase regulatory subunit of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000006312",
#             "symbol": "RPN7",
#             "name": "Essential non-ATPase regulatory subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000005787",
#             "symbol": "RPN8",
#             "name": "Essential non-ATPase regulatory subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002835",
#             "symbol": "RPN9",
#             "name": "Non-ATPase regulatory subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000001628",
#             "symbol": "RPT1",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002165",
#             "symbol": "RPT2",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002802",
#             "symbol": "RPT3",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000005785",
#             "symbol": "RPT4",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000005643",
#             "symbol": "RPT5",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000003016",
#             "symbol": "RPT6",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002979",
#             "symbol": "SCL1",
#             "name": "Alpha 1 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000007235",
#             "symbol": "SEM1",
#             "name": "19S proteasome regulatory particle lid subcomplex component"
#         },
#         {
#             "sgdid": "S000002584",
#             "symbol": "UBC1",
#             "name": "Ubiquitin-conjugating enzyme"
#         },
#         {
#             "sgdid": "S000000286",
#             "symbol": "UBC4",
#             "name": "Ubiquitin-conjugating enzyme (E2)"
#         },
#         {
#             "sgdid": "S000002466",
#             "symbol": "UBC5",
#             "name": "Ubiquitin-conjugating enzyme"
#         },
#         {
#             "sgdid": "S000001906",
#             "symbol": "UBP6",
#             "name": "Ubiquitin-specific protease"
#         }
#     ],
#     "termid": "GO:0000502",
#     "children": [
#         {
#             "id": "GO:1990111",
#             "name": "spermatoproteasome complex"
#         },
#         {
#             "id": "GO:0031597",
#             "name": "cytosolic proteasome complex"
#         },
#         {
#             "id": "GO:0031595",
#             "name": "nuclear proteasome complex"
#         }
#     ],
#     "name": "proteasome complex"
# }
# {
#     "definition": "The aggregation, arrangement and bonding together of a mature, active proteasome complex.",
#     "namespace": "biological_process",
#     "parents": [
#         {
#             "id": "GO:0043623",
#             "name": "cellular protein complex assembly"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000001689",
#             "symbol": "ADD66",
#             "name": "Protein involved in 20S proteasome assembly"
#         },
#         {
#             "sgdid": "S000001887",
#             "symbol": "BLM10",
#             "name": "Proteasome activator"
#         },
#         {
#             "sgdid": "S000001022",
#             "symbol": "ECM29",
#             "name": "Scaffold protein"
#         },
#         {
#             "sgdid": "S000004798",
#             "symbol": "HSC82",
#             "name": "Cytoplasmic chaperone of the Hsp90 family"
#         },
#         {
#             "sgdid": "S000006161",
#             "symbol": "HSP82",
#             "name": "Hsp90 chaperone"
#         },
#         {
#             "sgdid": "S000004011",
#             "symbol": "IRC25",
#             "name": "Component of a heterodimeric Poc4p-Irc25p chaperone"
#         },
#         {
#             "sgdid": "S000005582",
#             "symbol": "NOB1",
#             "name": "Protein involved in proteasomal and 40S ribosomal subunit biogenesis"
#         },
#         {
#             "sgdid": "S000004189",
#             "symbol": "PBA1",
#             "name": "Protein involved in 20S proteasome assembly"
#         },
#         {
#             "sgdid": "S000006065",
#             "symbol": "POC4",
#             "name": "Component of a heterodimeric Poc4p-Irc25p chaperone"
#         },
#         {
#             "sgdid": "S000001946",
#             "symbol": "PRE4",
#             "name": "Beta 7 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000001243",
#             "symbol": "RPN10",
#             "name": "Non-ATPase base subunit of the 19S RP of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000001948",
#             "symbol": "RPN12",
#             "name": "Subunit of the 19S regulatory particle of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000001337",
#             "symbol": "RPN2",
#             "name": "Subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002255",
#             "symbol": "RPN6",
#             "name": "Essential, non-ATPase regulatory subunit of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000002835",
#             "symbol": "RPN9",
#             "name": "Non-ATPase regulatory subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000007235",
#             "symbol": "SEM1",
#             "name": "19S proteasome regulatory particle lid subcomplex component"
#         },
#         {
#             "sgdid": "S000004803",
#             "symbol": "SPG5",
#             "name": "Protein required for proteasome assembly during quiescence"
#         },
#         {
#             "sgdid": "S000000377",
#             "symbol": "UMP1",
#             "name": "Chaperone required for correct maturation of the 20S proteasome"
#         }
#     ],
#     "termid": "GO:0043248",
#     "children": [
#         {
#             "id": "GO:1902906",
#             "name": "proteasome storage granule assembly"
#         },
#         {
#             "id": "GO:0080129",
#             "name": "proteasome core complex assembly"
#         },
#         {
#             "id": "GO:0070682",
#             "name": "proteasome regulatory particle assembly"
#         }
#     ],
#     "name": "proteasome assembly"
# }
# {
#     "gene_count": 44,
#     "interactions": [
#         {
#             "score": 4.09251991349109,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YHR027C"
#         },
#         {
#             "score": 3.9246448715772098,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YKL145W"
#         },
#         {
#             "score": 3.23870651919886,
#             "interaction": "CC",
#             "target": "YNL073W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 3.19240628145999,
#             "interaction": "CC",
#             "target": "YOR261C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 3.01021089125915,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YDL007W"
#         },
#         {
#             "score": 3.01021089125915,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YIL075C"
#         },
#         {
#             "score": 3.01021089125909,
#             "interaction": "CC",
#             "target": "YOR117W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.8805362537206296,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YHR200W"
#         },
#         {
#             "score": 2.7867325444038396,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YKL213C"
#         },
#         {
#             "score": 2.75296252139601,
#             "interaction": "CC",
#             "target": "YOR259C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.32128447863566,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YBL076C"
#         },
#         {
#             "score": 1.01994430577895,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YLL018C"
#         },
#         {
#             "score": 0.725172398615405,
#             "interaction": "CC",
#             "target": "YLR421C",
#             "source": "YCR097W"
#         },
#         {
#             "score": 1.6374793093713897,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YGL048C"
#         },
#         {
#             "score": 1.5995111057220301,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YLR388W"
#         },
#         {
#             "score": 1.53320577451338,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YLR260W"
#         },
#         {
#             "score": 1.41026616899726,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YCL057W"
#         },
#         {
#             "score": 1.403787467437,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YDL007W"
#         },
#         {
#             "score": 1.0994189119898399,
#             "interaction": "CX",
#             "target": "YLR449W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.0806316482950502,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YBR042C"
#         },
#         {
#             "score": 0.968386695791717,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YDR427W"
#         },
#         {
#             "score": 0.9503619708216199,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YGL011C"
#         },
#         {
#             "score": 0.9322893451792561,
#             "interaction": "CX",
#             "target": "YMR073C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 0.916215578587456,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YDR288W"
#         },
#         {
#             "score": 0.8398177490939499,
#             "interaction": "CX",
#             "target": "YLR421C",
#             "source": "YLR165C"
#         },
#         {
#             "score": 0.818579705125972,
#             "interaction": "CX",
#             "target": "YOR265W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.92153996007125,
#             "interaction": "GT",
#             "target": "YPR189W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.8688136283607,
#             "interaction": "GT",
#             "target": "YNL139C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.86458115374614,
#             "interaction": "GT",
#             "target": "YPL015C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.85839828151151,
#             "interaction": "GT",
#             "target": "YNL030W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.8509956644598502,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKL213C"
#         },
#         {
#             "score": 1.82183061183015,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR156W"
#         },
#         {
#             "score": 1.8204035964576102,
#             "interaction": "GT",
#             "target": "YML102W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.8146205842534098,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR073W"
#         },
#         {
#             "score": 1.75083017770279,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YFR010W"
#         },
#         {
#             "score": 1.69980019915609,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBL002W"
#         },
#         {
#             "score": 1.6756024896776998,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHL030W"
#         },
#         {
#             "score": 1.62746803117591,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR082C"
#         },
#         {
#             "score": 1.5780831151772299,
#             "interaction": "GT",
#             "target": "YMR201C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.57272685200782,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJL148W"
#         },
#         {
#             "score": 1.5199323601433,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YCR077C"
#         },
#         {
#             "score": 1.50824757287,
#             "interaction": "GT",
#             "target": "YML034W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.50605260508544,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YEL056W"
#         },
#         {
#             "score": 1.50508382265205,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR095C"
#         },
#         {
#             "score": 1.5023887943033098,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YCR002C"
#         },
#         {
#             "score": 1.50161878356343,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL116W"
#         },
#         {
#             "score": 1.4930506477493601,
#             "interaction": "GT",
#             "target": "YOL054W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.48571282044493,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YFR013W"
#         },
#         {
#             "score": 1.48278365082455,
#             "interaction": "GT",
#             "target": "YOR005C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.48099128899454,
#             "interaction": "GT",
#             "target": "YPR161C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.48052531862335,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGL090W"
#         },
#         {
#             "score": 1.4788632711238199,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YIL036W"
#         },
#         {
#             "score": 1.47598194915501,
#             "interaction": "GT",
#             "target": "YMR179W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.45975915909518,
#             "interaction": "GT",
#             "target": "YNL031C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.4596507426307601,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKL023W"
#         },
#         {
#             "score": 1.45854912573849,
#             "interaction": "GT",
#             "target": "YNL136W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.4430104213725001,
#             "interaction": "GT",
#             "target": "YOR304W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.44207171520711,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGR275W"
#         },
#         {
#             "score": 1.4304444499188,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKR098C"
#         },
#         {
#             "score": 1.4234973867140501,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YCL061C"
#         },
#         {
#             "score": 1.4154560317421299,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR137C"
#         },
#         {
#             "score": 1.4088509394068403,
#             "interaction": "GT",
#             "target": "YPR164W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.4048226332903102,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHR191C"
#         },
#         {
#             "score": 1.39478106980914,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL002C"
#         },
#         {
#             "score": 1.39355732749831,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YIR008C"
#         },
#         {
#             "score": 1.39302592027565,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YIL112W"
#         },
#         {
#             "score": 1.3868246963148898,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGR086C"
#         },
#         {
#             "score": 1.3856508604185602,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLL002W"
#         },
#         {
#             "score": 1.3838425809138601,
#             "interaction": "GT",
#             "target": "YMR224C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.3823085462767,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR363W-A"
#         },
#         {
#             "score": 1.38034383177223,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJL115W"
#         },
#         {
#             "score": 1.3734847604408202,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YAR002W"
#         },
#         {
#             "score": 1.37179885214947,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR180W"
#         },
#         {
#             "score": 1.37083130352182,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER161C"
#         },
#         {
#             "score": 1.37045445903831,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER068W"
#         },
#         {
#             "score": 1.36873959521799,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR009C"
#         },
#         {
#             "score": 1.35900192013741,
#             "interaction": "GT",
#             "target": "YMR144W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.35538328384226,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR475C"
#         },
#         {
#             "score": 1.3493717047648002,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER125W"
#         },
#         {
#             "score": 1.34464344947572,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL020C"
#         },
#         {
#             "score": 1.34419257293722,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR098W"
#         },
#         {
#             "score": 1.34252303811896,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGL043W"
#         },
#         {
#             "score": 1.34248306977426,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR088C"
#         },
#         {
#             "score": 1.34207800643115,
#             "interaction": "GT",
#             "target": "YPL022W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.34117910268448,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGL195W"
#         },
#         {
#             "score": 1.3407165608282,
#             "interaction": "GT",
#             "target": "YNR048W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.34068772900585,
#             "interaction": "GT",
#             "target": "YOR144C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.33481868621156,
#             "interaction": "GT",
#             "target": "YOL094C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.3303955924058601,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR140C"
#         },
#         {
#             "score": 1.3273702006251,
#             "interaction": "GT",
#             "target": "YOR346W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.32351409034433,
#             "interaction": "GT",
#             "target": "YNL215W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.32173273875736,
#             "interaction": "GT",
#             "target": "YOR026W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.31975971504729,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKL010C"
#         },
#         {
#             "score": 1.3192975948888002,
#             "interaction": "GT",
#             "target": "YLR449W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.31752233073495,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR175W"
#         },
#         {
#             "score": 1.3164372116508,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGR188C"
#         },
#         {
#             "score": 1.3148600625101101,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR087W"
#         },
#         {
#             "score": 1.3109571790671002,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKL160W"
#         },
#         {
#             "score": 1.3078543741093402,
#             "interaction": "GT",
#             "target": "YOR014W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.3057966488548998,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL059C"
#         },
#         {
#             "score": 1.30548690549342,
#             "interaction": "GT",
#             "target": "YMR078C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.30414157215345,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR181C"
#         },
#         {
#             "score": 1.30051206876122,
#             "interaction": "GT",
#             "target": "YOR340C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.29896509814255,
#             "interaction": "GT",
#             "target": "YNL021W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2986671076996001,
#             "interaction": "GT",
#             "target": "YOR172W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.29819729780623,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER116C"
#         },
#         {
#             "score": 1.29643292898822,
#             "interaction": "GT",
#             "target": "YML111W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.29590542303202,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGL213C"
#         },
#         {
#             "score": 1.2956496159777098,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR245C"
#         },
#         {
#             "score": 1.29404853930368,
#             "interaction": "GT",
#             "target": "YMR223W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.29335775485994,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR440W"
#         },
#         {
#             "score": 1.2911777773036202,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKL020C"
#         },
#         {
#             "score": 1.29013860104881,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR010W"
#         },
#         {
#             "score": 1.2895811095919398,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR053W"
#         },
#         {
#             "score": 1.28809258842367,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHR200W"
#         },
#         {
#             "score": 1.28786336440187,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHR154W"
#         },
#         {
#             "score": 1.28671229342962,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHL022C"
#         },
#         {
#             "score": 1.2861234650453102,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBL008W"
#         },
#         {
#             "score": 1.28488237050085,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YHR167W"
#         },
#         {
#             "score": 1.2801306653328601,
#             "interaction": "GT",
#             "target": "YNR010W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2787053946861102,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER007C-A"
#         },
#         {
#             "score": 1.2725696430204099,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YCL011C"
#         },
#         {
#             "score": 1.26993428217891,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL122W"
#         },
#         {
#             "score": 1.2691151426979599,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL013W"
#         },
#         {
#             "score": 1.2684610279521102,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGR135W"
#         },
#         {
#             "score": 1.26793873627899,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YFL013C"
#         },
#         {
#             "score": 1.2678638497803798,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YEL018W"
#         },
#         {
#             "score": 1.2664616568180702,
#             "interaction": "GT",
#             "target": "YMR227C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2652419400186201,
#             "interaction": "GT",
#             "target": "YMR106C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.26492695829525,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR254W"
#         },
#         {
#             "score": 1.26295970509592,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YIL097W"
#         },
#         {
#             "score": 1.2620413627246299,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJL092W"
#         },
#         {
#             "score": 1.26176866824948,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGR071C"
#         },
#         {
#             "score": 1.25819263583688,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBL088C"
#         },
#         {
#             "score": 1.25508857303706,
#             "interaction": "GT",
#             "target": "YNL248C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.25302796757674,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YGL163C"
#         },
#         {
#             "score": 1.25215448993906,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YFR019W"
#         },
#         {
#             "score": 1.2505880782501202,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YAR003W"
#         },
#         {
#             "score": 1.2491551830044099,
#             "interaction": "GT",
#             "target": "YML069W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24887846182044,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YCR066W"
#         },
#         {
#             "score": 1.24752625433624,
#             "interaction": "GT",
#             "target": "YPL153C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2466809967991,
#             "interaction": "GT",
#             "target": "YPR007C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24516984921676,
#             "interaction": "GT",
#             "target": "YNL323W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24325496863087,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR126C"
#         },
#         {
#             "score": 1.2432503783883797,
#             "interaction": "GT",
#             "target": "YOR001W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24150361938526,
#             "interaction": "GT",
#             "target": "YOR273C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24117591930436,
#             "interaction": "GT",
#             "target": "YOL004W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.24012612478214,
#             "interaction": "GT",
#             "target": "YMR284W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2390267022110402,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER095W"
#         },
#         {
#             "score": 1.23730605430357,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR182W"
#         },
#         {
#             "score": 1.23637880112817,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YIL084C"
#         },
#         {
#             "score": 1.23574285004955,
#             "interaction": "GT",
#             "target": "YML062C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.23424544938979,
#             "interaction": "GT",
#             "target": "YOR213C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.23341374388707,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR385C"
#         },
#         {
#             "score": 1.23317058718322,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR043C"
#         },
#         {
#             "score": 1.2330964509028102,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR052W"
#         },
#         {
#             "score": 1.23273345323524,
#             "interaction": "GT",
#             "target": "YPR046W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.23254157648675,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YFR009W"
#         },
#         {
#             "score": 1.2307489285837099,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR032W"
#         },
#         {
#             "score": 1.22990938312566,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YAL013W"
#         },
#         {
#             "score": 1.2278394785693898,
#             "interaction": "GT",
#             "target": "YOR038C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2224742120108798,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLL039C"
#         },
#         {
#             "score": 1.22235408602277,
#             "interaction": "GT",
#             "target": "YOR189W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.22146575132725,
#             "interaction": "GT",
#             "target": "YNL147W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.22140093928846,
#             "interaction": "GT",
#             "target": "YPL167C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2210877480750901,
#             "interaction": "GT",
#             "target": "YOL072W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.22108653202911,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR215W"
#         },
#         {
#             "score": 1.2205852580528997,
#             "interaction": "GT",
#             "target": "YPR135W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2192686429572799,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR135C"
#         },
#         {
#             "score": 1.21887210500336,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YJR035W"
#         },
#         {
#             "score": 1.2180066316197702,
#             "interaction": "GT",
#             "target": "YNL097C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.21712344799365,
#             "interaction": "GT",
#             "target": "YMR055C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2171071287862198,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YER178W"
#         },
#         {
#             "score": 1.21658915258913,
#             "interaction": "GT",
#             "target": "YNL330C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.2163898988553798,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YKR101W"
#         },
#         {
#             "score": 1.216173282183,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YBR111W-A"
#         },
#         {
#             "score": 1.2122892760500001,
#             "interaction": "GT",
#             "target": "YNL201C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.21088272478043,
#             "interaction": "GT",
#             "target": "YNL227C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.20918990496345,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR075W"
#         },
#         {
#             "score": 1.20775890297803,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDR139C"
#         },
#         {
#             "score": 1.20443109344405,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL005C"
#         },
#         {
#             "score": 1.07603228674108,
#             "interaction": "GT",
#             "target": "YPL002C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 1.03593295828269,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YLR369W"
#         },
#         {
#             "score": 1.03472302711065,
#             "interaction": "GT",
#             "target": "YLR421C",
#             "source": "YDL182W"
#         },
#         {
#             "score": 4.478322517221259,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YIL075C"
#         },
#         {
#             "score": 4.4567909573434505,
#             "interaction": "HT",
#             "target": "YOR259C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 4.44293716764063,
#             "interaction": "HT",
#             "target": "YOR117W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 4.44193360945843,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDR427W"
#         },
#         {
#             "score": 4.44193360884019,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YFR004W"
#         },
#         {
#             "score": 4.44193360527688,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YHR200W"
#         },
#         {
#             "score": 4.44193357955704,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YER021W"
#         },
#         {
#             "score": 4.44118777347097,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDL007W"
#         },
#         {
#             "score": 4.4397403949669805,
#             "interaction": "HT",
#             "target": "YPR108W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 4.439578141905611,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YKL145W"
#         },
#         {
#             "score": 4.439100759129451,
#             "interaction": "HT",
#             "target": "YOR261C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 4.43897511101181,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDL147W"
#         },
#         {
#             "score": 4.43789944495268,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDR394W"
#         },
#         {
#             "score": 4.43751192052249,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YHR027C"
#         },
#         {
#             "score": 4.435594863649571,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDL097C"
#         },
#         {
#             "score": 4.4260731225450805,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YFR052W"
#         },
#         {
#             "score": 4.42607304014325,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YGL048C"
#         },
#         {
#             "score": 4.40689754291129,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YFR010W"
#         },
#         {
#             "score": 4.36945705156975,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YHL030W"
#         },
#         {
#             "score": 4.33265829401703,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDR363W-A"
#         },
#         {
#             "score": 4.23644252785249,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YGR232W"
#         },
#         {
#             "score": 3.8019527141716005,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YBR080C"
#         },
#         {
#             "score": 3.5894303543393997,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YCR014C"
#         },
#         {
#             "score": 3.5838390806975697,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDR108W"
#         },
#         {
#             "score": 3.4015374396669196,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YKR095W"
#         },
#         {
#             "score": 3.1348686805094097,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YHR047C"
#         },
#         {
#             "score": 3.1259575065750895,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YGL004C"
#         },
#         {
#             "score": 3.1210079796138297,
#             "interaction": "HT",
#             "target": "YMR191W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.9557422929014803,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YCR093W"
#         },
#         {
#             "score": 2.88758835590791,
#             "interaction": "HT",
#             "target": "YNL064C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.8776663332665495,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YDR326C"
#         },
#         {
#             "score": 2.81148543240247,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YEL021W"
#         },
#         {
#             "score": 2.6284601922671698,
#             "interaction": "HT",
#             "target": "YNL004W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.57034280060224,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YHR001W"
#         },
#         {
#             "score": 2.57034280060224,
#             "interaction": "HT",
#             "target": "YOL078W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.5697660361945,
#             "interaction": "HT",
#             "target": "YML026C",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.4776697846007796,
#             "interaction": "HT",
#             "target": "YLR421C",
#             "source": "YER172C"
#         },
#         {
#             "score": 2.4497217865398797,
#             "interaction": "HT",
#             "target": "YMR314W",
#             "source": "YLR421C"
#         },
#         {
#             "score": 2.41764662685696,
# ...
#         {
#             "score": 1.19377905158315,
#             "interaction": "HT",
#             "target": "YPL012W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.19012130167581,
#             "interaction": "HT",
#             "target": "YOR204W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.16670929932035,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YCR009C"
#         },
#         {
#             "score": 1.16130722899105,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDR138W"
#         },
#         {
#             "score": 1.1476638926233602,
#             "interaction": "HT",
#             "target": "YOR063W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13577655725932,
#             "interaction": "HT",
#             "target": "YLL045C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDL213C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDR238C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YHR099W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YIL076W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YMR146C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YNL139C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13182553432305,
#             "interaction": "HT",
#             "target": "YOL004W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDR449C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YLR129W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YMR242C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YNL069C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YNL307C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YOL120C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.13135908371695,
#             "interaction": "HT",
#             "target": "YPR131C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.09409426250857,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDR471W"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YBR084W"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YCR057C"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YJL033W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YKR024C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YLR222C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.08054177055965,
#             "interaction": "HT",
#             "target": "YLR409C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.03791410813281,
#             "interaction": "HT",
#             "target": "YOR312C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.03774882763421,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YBR279W"
#         },
#         {
#             "score": 1.03774882763421,
#             "interaction": "HT",
#             "target": "YKL152C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.03774882763421,
#             "interaction": "HT",
#             "target": "YML073C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.03774882763421,
#             "interaction": "HT",
#             "target": "YNL106C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.03598624017975,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YFR044C"
#         },
#         {
#             "score": 1.00985248038439,
#             "interaction": "HT",
#             "target": "YJL174W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 1.00083601242373,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDR099W"
#         },
#         {
#             "score": 1.00083601242373,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YGL195W"
#         },
#         {
#             "score": 1.00083601242373,
#             "interaction": "HT",
#             "target": "YHR064C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 0.97357855081999,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YDL014W"
#         },
#         {
#             "score": 0.9684163616247751,
#             "interaction": "HT",
#             "target": "YLR075W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 0.9684163616247751,
#             "interaction": "HT",
#             "target": "YNL061W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 0.967046428619342,
#             "interaction": "HT",
#             "target": "YGR202C",
#             "source": "YBR031W"
#         },
#         {
#             "score": 3.76385493076639,
#             "interaction": "LC",
#             "target": "YJL174W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 3.4387912079100196,
#             "interaction": "LC",
#             "target": "YOR098C",
#             "source": "YGR202C"
#         },
#         {
#             "score": 3.37144463989094,
#             "interaction": "LC",
#             "target": "YGR202C",
#             "source": "YGL137W"
#         },
#         {
#             "score": 3.35433040891174,
#             "interaction": "LC",
#             "target": "YOR181W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 3.26686221664213,
#             "interaction": "LC",
#             "target": "YNL189W",
#             "source": "YGR202C"
#         },
#         {
#             "score": 3.3433039474286197,
#             "interaction": "TS",
#             "target": "YGR202C",
#             "source": "YGR010W"
#         },
#         {
#             "score": 3.02716790069746,
#             "interaction": "TS",
#             "target": "YGR202C",
#             "source": "YGR007W"
#         },
#         {
#             "score": 2.63563087445786,
#             "interaction": "TS",
#             "target": "YLR328W",
#             "source": "YGR202C"
#         }
#     ],
#     "go": {
#         "score": 0.351163,
#         "definition": "Any process in which the proteasome is transported to, or maintained in, a specific location.",
#         "fdr": 9.13242e-05,
#         "name": "proteasome localization",
#         "goid": "GO:0031144"
#     },
#     "genes": [
#         {
#             "sgdid": "S000003434",
#             "orf": "YGR202C",
#             "symbol": "PCT1",
#             "name": "Cholinephosphate cytidylyltransferase"
#         },
#         {
#             "sgdid": "S000001900",
#             "orf": "YFR004W",
#             "symbol": "RPN11",
#             "name": "Metalloprotease subunit of 19S regulatory particle"
#         },
#         {
#             "sgdid": "S000005889",
#             "orf": "YOR362C",
#             "symbol": "PRE10",
#             "name": "Alpha 7 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000005133",
#             "orf": "YNL189W",
#             "symbol": "SRP1",
#             "name": "Karyopherin alpha homolog"
#         },
#         {
#             "sgdid": "S000001450",
#             "orf": "YIR011C",
#             "symbol": "STS1",
#             "name": "Protein required for localizing proteasomes to the nucleus"
#         }
#     ],
#     "termid": "CLIXO:9355",
#     "name": "proteasome localization"
# }
# {
#     "definition": "Interacting selectively and non-covalently with a proteasome, a large multisubunit protein complex that catalyzes protein degradation.",
#     "namespace": "molecular_function",
#     "parents": [
#         {
#             "id": "GO:0032403",
#             "name": "protein complex binding"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000001887",
#             "symbol": "BLM10",
#             "name": "Proteasome activator"
#         },
#         {
#             "sgdid": "S000001094",
#             "symbol": "CIC1",
#             "name": "Essential protein that interacts with proteasome components"
#         },
#         {
#             "sgdid": "S000005099",
#             "symbol": "CUZ1",
#             "name": "Protein with a role in the ubiquitin-proteasome pathway"
#         },
#         {
#             "sgdid": "S000000672",
#             "symbol": "FUB1",
#             "name": "Proteasome-binding protein"
#         },
#         {
#             "sgdid": "S000000499",
#             "symbol": "PCA1",
#             "name": "Cadmium transporting P-type ATPase"
#         },
#         {
#             "sgdid": "S000000763",
#             "symbol": "RAD23",
#             "name": "Protein with ubiquitin-like N terminus"
#         },
#         {
#             "sgdid": "S000004413",
#             "symbol": "RPN13",
#             "name": "Subunit of the 19S regulatory particle of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000004803",
#             "symbol": "SPG5",
#             "name": "Protein required for proteasome assembly during quiescence"
#         }
#     ],
#     "termid": "GO:0070628",
#     "name": "proteasome binding"
# }
# {
#     "definition": "The aggregation, arrangement and bonding together of a mature, active 20S proteasome core particle complex that does not contain any regulatory particles.",
#     "namespace": "biological_process",
#     "parents": [
#         {
#             "id": "GO:0043248",
#             "name": "proteasome assembly"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000006307",
#             "symbol": "PRE2",
#             "name": "Beta 5 subunit of the 20S proteasome"
#         },
#         {
#             "sgdid": "S000003367",
#             "symbol": "PRE9",
#             "name": "Alpha 3 subunit of the 20S proteasome"
#         }
#     ],
#     "termid": "GO:0080129",
#     "name": "proteasome core complex assembly"
# }
# {
#     "definition": "The aggregation, arrangement and bonding together of a set of components to form a proteasome storage granule.",
#     "namespace": "biological_process",
#     "parents": [
#         {
#             "id": "GO:0043248",
#             "name": "proteasome assembly"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000002976",
#             "symbol": "PMA1",
#             "name": "Plasma membrane P2-type H+-ATPase"
#         },
#         {
#             "sgdid": "S000001900",
#             "symbol": "RPN11",
#             "name": "Metalloprotease subunit of 19S regulatory particle"
#         },
#         {
#             "sgdid": "S000000331",
#             "symbol": "VMA2",
#             "name": "Subunit B of V1 peripheral membrane domain of vacuolar H+-ATPase"
#         }
#     ],
#     "termid": "GO:1902906",
#     "name": "proteasome storage granule assembly"
# }
# {
#     "definition": "The aggregation, arrangement and bonding together of a mature, active proteasome regulatory particle complex.",
#     "namespace": "biological_process",
#     "parents": [
#         {
#             "id": "GO:0043248",
#             "name": "proteasome assembly"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000000476",
#             "symbol": "HSM3",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000001269",
#             "symbol": "NAS2",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000003464",
#             "symbol": "NAS6",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000002972",
#             "symbol": "RPN14",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000001628",
#             "symbol": "RPT1",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002165",
#             "symbol": "RPT2",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002802",
#             "symbol": "RPT3",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000005785",
#             "symbol": "RPT4",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000005643",
#             "symbol": "RPT5",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000003016",
#             "symbol": "RPT6",
#             "name": "ATPase of the 19S regulatory particle of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000002268",
#             "symbol": "TMA17",
#             "name": "ATPase dedicated chaperone that adapts proteasome assembly to stress"
#         }
#     ],
#     "termid": "GO:0070682",
#     "name": "proteasome regulatory particle assembly"
# }
# {
#     "definition": "A multisubunit complex, which caps one or both ends of the proteasome core complex. This complex recognizes and unfolds ubiquitinated proteins, and translocates them to the proteasome core complex.",
#     "namespace": "cellular_component",
#     "parents": [
#         {
#             "id": "GO:0043234",
#             "name": "protein complex"
#         },
#         {
#             "id": "GO:0044424",
#             "name": "intracellular part"
#         }
#     ],
#     "genes": [
#         {
#             "sgdid": "S000003464",
#             "symbol": "NAS6",
#             "name": "Evolutionarily conserved 19S regulatory particle assembly-chaperone"
#         },
#         {
#             "sgdid": "S000001948",
#             "symbol": "RPN12",
#             "name": "Subunit of the 19S regulatory particle of the 26S proteasome lid"
#         },
#         {
#             "sgdid": "S000005787",
#             "symbol": "RPN8",
#             "name": "Essential non-ATPase regulatory subunit of the 26S proteasome"
#         },
#         {
#             "sgdid": "S000001906",
#             "symbol": "UBP6",
#             "name": "Ubiquitin-specific protease"
#         }
#     ],
#     "termid": "GO:0005838",
#     "children": [
#         {
#             "id": "GO:0031598",
#             "name": "nuclear proteasome regulatory particle"
#         },
#         {
#             "id": "GO:0031600",
#             "name": "cytosolic proteasome regulatory particle"
#         }
#     ],
#     "name": "proteasome regulatory particle"
# }
